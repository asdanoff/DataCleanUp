# %% [markdown]
# **Problem 1**
# Clean up the file. This means getting rid of duplicates; you can assume that no student can register for the same course more than once. How many duplicate records do you find? Some of the fields have bad or missing values; repair those that you can (and explain what a repair means).

# %%
import pandas as pd
import csv
import sys

# %% [markdown]
# Opening the data: Because of the number of corrupted lines/entries in the data, it was impossible to open the data as a full file by reading it into a pandas dataframe or even by reading it in line by line. The code below tries to read each line, and appends only the lines that are open-able to a list, good_lines. We count the number of bad lines

# %%
# Note - change file path or put csv in your directory to run this code yourself
with open('/Users/amydanoff/Desktop/APCOMP221/dirty_sample_small.csv') as f:
    length = 661486
    good_lines = []
    bad_lines = 0
    for i in range(length):
        try:
            value = f.readline()
            good_lines.append(value)
        except:
            bad_lines += 1
    print("This file has", bad_lines, "unreadable lines")
# Out:
# This file has 2337 unreadable lines

# %%
print("We are left with", len(good_lines), "readable lines.")
# Out:
# We are left with 659149 readable lines.

# %% [markdown]
# Read in header to figure out which categories we are supposed to have in our dataframe.

# %%
# Create header dataframe from header csv
header = pd.DataFrame.from_csv('dirty_sample_small_header.csv')
header.loc[-1] = ['course_id']
header.index = header.index + 1
header = header.sort_index()
header = header.transpose()
header
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-10cd8caedf8b> in <module>()
#       1 # Create header dataframe from header csv
# ----> 2 header = pd.DataFrame.from_csv('dirty_sample_small_header.csv')
#       3 header.loc[-1] = ['course_id']
#       4 header.index = header.index + 1
#       5 header = header.sort_index()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in from_csv(cls, path, header, sep, index_col, parse_dates, encoding, tupleize_cols, infer_datetime_format)
#    1577                           parse_dates=parse_dates, index_col=index_col,
#    1578                           encoding=encoding, tupleize_cols=tupleize_cols,
# -> 1579                           infer_datetime_format=infer_datetime_format)
#    1580
#    1581     def to_sparse(self, fill_value=None, kind='block'):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'dirty_sample_small_header.csv' does not exist

# %%
good_lines[:2]
# Out:
# ['_Nations,,Latin America and the Caribbean,-23.4507,-46.5262,m,1980,m,,0.7,4/24/18 23:35,35:15.4,35:41.9,9,1,0,1,,,,,,,Student,0,0,0,audit,1,,,,\n',
#  'HarvardX/PH525.1x/1T2018,28454,TRUE,FALSE,FALSE,FALSE,177.18.230.216,BR,Brazil,Americas,Guarulhos,SP,Sao Paulo,,South America,Developing_Nations,,Latin America and the Caribbean,-23.4507,-46.5262,m,1980,m,,0.7,4/24/18 23:35,35:15.4,35:41.9,9,1,0,1,,,,,,,Student,0,0,0,audit,1,,,,\n']

# %%
df = pd.DataFrame([sub.split(",") for sub in good_lines])

# %%
# TEST - ensure that dataframe works
print(len(df))
# Out:
# 659149

# %%
df.head()
# Out:
#                          0      1                                2         3   \
# 0                  _Nations         Latin America and the Caribbean  -23.4507
# 1  HarvardX/PH525.1x/1T2018  28454                             TRUE     FALSE
# 2  HarvardX/PH525.1x/1T2018  28454                             TRUE     FALSE
# 3  HarvardX/PH525.1x/1T2018  28454                             TRUE     FALSE
# 4  HarvardX/PH525.1x/1T2018  43100                            FALSE
#
#          4      5               6   7       8         9   ...        38    39  \
# 0  -46.5262      m            1980   m               0.7  ...      None  None
# 1     FALSE  FALSE  177.18.230.216  BR  Brazil  Americas  ...   Student     0
# 2     FALSE  FALSE  177.18.230.216  BR  Brazil  Americas  ...   Student     0
# 3     FALSE  FALSE  177.18.230.216  BR  Brazil  Americas  ...   Student     0
# 4     FALSE  FALSE   213.249.56.36  GR  Greece    Europe  ...   Student     0
#
#      40    41     42    43    44    45    46    47
# 0  None  None   None  None  None  None  None  None
# 1     0     0  audit     1                      \n
# 2     0     0  audit     1                      \n
# 3     0     0  audit     1                      \n
# 4     0     0  audit     1                      \n
#
# [5 rows x 48 columns]

# %%
df.drop([0])
# Out:
#                               0      1      2      3      4      5   \
# 1       HarvardX/PH525.1x/1T2018  28454   TRUE  FALSE  FALSE  FALSE
# 2       HarvardX/PH525.1x/1T2018  28454   TRUE  FALSE  FALSE  FALSE
# 3       HarvardX/PH525.1x/1T2018  28454   TRUE  FALSE  FALSE  FALSE
# 4       HarvardX/PH525.1x/1T2018  43100  FALSE         FALSE  FALSE
# 5       HarvardX/PH525.1x/1T2018  43100  FALSE         FALSE  FALSE
# 6       HarvardX/PH525.1x/1T2018  43100  FALSE         FALSE  FALSE
# 7       HarvardX/PH525.1x/1T2018  43100  FALSE         FALSE  FALSE
# 8       HarvardX/PH525.1x/1T2018  43100  FALSE         FALSE  FALSE
# 9       HarvardX/PH525.1x/1T2018  43100  FALSE         FALSE  FALSE
# 10      HarvardX/PH525.1x/1T2018  43100  FALSE         FALSE  FALSE
# 11      HarvardX/PH525.1x/1T2018  43100  FALSE         FALSE  FALSE
# 12      HarvardX/PH525.1x/1T2018  44413  FALSE         FALSE  FALSE
# 13      HarvardX/PH525.1x/1T2018  44413  FALSE         FALSE  FALSE
# 14      HarvardX/PH525.1x/1T2018  44413  FALSE         FALSE  FALSE
# 15      HarvardX/PH525.1x/1T2018  44413  FALSE         FALSE  FALSE
# 16      HarvardX/PH525.1x/1T2018  44413  FALSE         FALSE  FALSE
# 17      HarvardX/PH525.1x/1T2018  44413  FALSE         FALSE  FALSE
# 18      HarvardX/PH525.1x/1T2018  44413  FALSE         FALSE  FALSE
# 11         0  audit     1                      \n
# 12         0  audit     1                      \n
# 13         0  audit     1                      \n
# 14         0  audit     1                      \n
# 15         0  audit     1                      \n
# 16         0  audit     1                      \n
# 17         0  audit     1                      \n
# 18         0  audit     1                      \n
# 19         0  audit     1                      \n
# 20         0  audit     1                      \n
# 21         0  audit     1                      \n
# 22         0  audit     1                      \n
# 23         0  audit     1                      \n
# 24         0  audit     1                      \n
# 25         0  audit     1                      \n
# 26         0  audit     1                      \n
# 27         0  audit     1                      \n
# 28         0  audit     1                      \n
# 29         0  audit     1                      \n
# 30         0  audit     1                      \n
# ...      ...    ...   ...   ...   ...   ...   ...
# 659119  None   None  None  None  None  None  None
# 659120  None   None  None  None  None  None  None
# 659121  None   None  None  None  None  None  None
# 659122  None   None  None  None  None  None  None
# 659123  None   None  None  None  None  None  None
# 659124  None   None  None  None  None  None  None
# 659125  None   None  None  None  None  None  None
# 659126  None   None  None  None  None  None  None
# 659127  None   None  None  None  None  None  None
# 659128  None   None  None  None  None  None  None
# 659129  None   None  None  None  None  None  None
# 659130  None   None  None  None  None  None  None
# 659131  None   None  None  None  None  None  None
# 659132  None   None  None  None  None  None  None
# 659133  None   None  None  None  None  None  None
# 659134  None   None  None  None  None  None  None
# 659135  None   None  None  None  None  None  None
# 659136  None   None  None  None  None  None  None
# 659137  None   None  None  None  None  None  None
# 659138  None   None  None  None  None  None  None
# 659139  None   None  None  None  None  None  None
# 659140  None   None  None  None  None  None  None
# 659141  None   None  None  None  None  None  None
# 659142  None   None  None  None  None  None  None
# 659143  None   None  None  None  None  None  None
# 659144  None   None  None  None  None  None  None
# 659145  None   None  None  None  None  None  None
# 659146  None   None  None  None  None  None  None
# 659147  None   None  None  None  None  None  None
# 659148  None   None  None  None  None  None  None
#
# [659148 rows x 48 columns]

# %%
my_header = header.iloc[0].reset_index()['course_id']
my_header
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f2423503af2f> in <module>()
# ----> 1 my_header = header.iloc[0].reset_index()['course_id']
#       2 my_header
#
# NameError: name 'header' is not defined

# %%
# Set header dataframe as header of main dataframe
df = df.rename(columns=my_header)

# %%
df.head()

# %%
df.drop([0])

# %% [markdown]
# **Removing Duplicate Records** Now that we have loaded our data into a workable dataframe, we can begin our analysis. We first look for duplicates within the 'user_id' column, a column that should have all unique values, to determine how many duplicate students we have in our dataframe (and thus need to remove).

# %%
# Find number of unique records in user_id column
unique_entries = df['user_id'].unique()
print("This dataset has", len(unique_entries), "unique entries")
print("Thus, we have", len(df) - len(unique_entries), "duplicate entries")

# %%
# Create data frame with only unique entries (based on user id)
unique_df = df.drop_duplicates(subset='user_id')

# %%
print(len(unique_df))

# %% [markdown]
# **Filling Missing Values** With our new dataframe (where non-unique rows have been dropped), we fill all missing values using a statistically representative draw from that column

# %%
import numpy as np

# %%
# Import methods written for reidentification pset
